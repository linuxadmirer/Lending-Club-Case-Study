# %% [markdown]
# ## import essential libs and load the file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
loan = pd.read_csv("loan.csv")
loan.head()
#loan.value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %%
loan.emp_length.value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %%
loan["emp_length"].mode()[0]
loan["emp_length"] = loan["emp_length"].fillna(loan["emp_length"].mode()[0])
loan.emp_length.value_counts()
# Out:
# 10+ years    9954
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %% [markdown]
# value count details about the colums

# %%
loanstat = ['acc_open_past_24mths','acc_now_delinq','addr_state','all_util','annual_inc','annual_inc_joint','application_type','avg_cur_bal','bc_open_to_buy','bc_util','chargeoff_within_12_mths','collection_recovery_fee','collections_12_mths_ex_med','delinq_2yrs','delinq_amnt','desc','dti','dti_joint','earliest_cr_line','emp_length','emp_title','fico_range_high','fico_range_low','funded_amnt','funded_amnt_inv','grade','home_ownership','id','il_util','initial_list_status','inq_fi','inq_last_12m','inq_last_6mths','installment','int_rate','issue_d','last_credit_pull_d','last_fico_range_high','last_fico_range_low','last_pymnt_amnt','last_pymnt_d','loan_amnt','loan_status','max_bal_bc','member_id','mo_sin_old_il_acct','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op','mo_sin_rcnt_tl','mort_acc','mths_since_last_delinq','mths_since_last_major_derog','mths_since_last_record','mths_since_rcnt_il','mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq','mths_since_recent_revol_delinq','next_pymnt_d','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m','num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','open_acc','open_acc_6m','open_il_12m','open_il_24m','open_il_6m','open_rv_12m','open_rv_24m','out_prncp','out_prncp_inv','pct_tl_nvr_dlq','percent_bc_gt_75','policy_code','pub_rec','pub_rec_bankruptcies','purpose','pymnt_plan','recoveries','revol_bal','revol_util','sub_grade','tax_liens','term','title','tot_coll_amt','tot_cur_bal','tot_hi_cred_lim','total_acc','total_bal_ex_mort','total_bal_il','total_bc_limit','total_cu_tl','total_il_high_credit_limit','total_pymnt','total_pymnt_inv','total_rec_int','total_rec_late_fee','total_rec_prncp','total_rev_hi_lim','url','verification_status','verified_status_joint','zip_code']

#for i in range(len(loanstat)):
#  print (loanstat[i])
#  x=loanstat[i]
#  print (loan[x].value_counts())
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
loan.shape
# Out:
# (39717, 111)

# %% [markdown]
# remove colums which are all NaN values and clean the data

# %%
loan1 = loan.dropna(axis=1)

# %%
loan1.shape
# Out:
# (39717, 44)

# %%
loan1.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
loan1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  object
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  emp_length               39717 non-null  object
#  11  home_ownership           39717 non-null  object
#  12  annual_inc               39717 non-null  float64
#  13  verification_status      39717 non-null  object
# ...

# %%
loan1.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... total_rec_prncp total_rec_int  \
# 0   10.65%       162.87     B        B2  ...         5000.00        863.16
# 1   15.27%        59.83     C        C4  ...          456.46        435.17
# 2   15.96%        84.33     C        C5  ...         2400.00        605.67
# 3   13.49%       339.31     C        C1  ...        10000.00       2214.92
# 4   12.69%        67.79     B        B5  ...         2475.94       1037.39
#
# ...

# %%
loan1.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'url', 'purpose', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt', 'policy_code',
#        'application_type', 'acc_now_delinq', 'delinq_amnt'],
#       dtype='object')

# %%
for i in range(len(loan1.columns)):
  print (loanstat[i])
  x=loanstat[i]
  print (loan[x].value_counts())
# Out:
# acc_open_past_24mths
# Series([], Name: acc_open_past_24mths, dtype: int64)
# acc_now_delinq
# 0    39717
# Name: acc_now_delinq, dtype: int64
# addr_state
# CA    7099
# NY    3812
# FL    2866
# TX    2727
# NJ    1850
# IL    1525
# PA    1517
# VA    1407
# GA    1398
# MA    1340
# OH    1223
# MD    1049
# AZ     879
# WA     840
# CO     792
# NC     788
# CT     751
# MI     720
# MO     686
# MN     615
# NV     497
# SC     472
# WI     460
# AL     452
# OR     451
# LA     436
# KY     325
# OK     299
# KS     271
# UT     258
# AR     245
# DC     214
# RI     198
# NM     189
# WV     177
# HI     174
# NH     171
# DE     114
# MT      85
# WY      83
# AK      80
# SD      64
# VT      54
# MS      19
# TN      17
# IN       9
# ID       6
# IA       5
# NE       5
# ME       3
# Name: addr_state, dtype: int64
# all_util
# Series([], Name: all_util, dtype: int64)
# annual_inc
# 60000.0    1505
# 50000.0    1057
# 40000.0     876
# 45000.0     830
# 30000.0     825
# ...

# %% [markdown]
# writing to file for analysis

# %%
print(loan1.shape)
loan1.to_csv("loan1.csv")
# Out:
# (39717, 44)

# %% [markdown]
# Drop the unwanted colums with non-unique values

# %%
drop_list =['pymnt_plan','initial_list_status','policy_code','application_type','acc_now_delinq','delinq_amnt']
#for i in range(len(loan1.columns)):
#  print (loanstat[i])
#  x=loanstat[i]
#  print (loan[x].value_counts())

#for i in range(drop_list):
loan1.drop(drop_list,axis =1,inplace=True)
loan1.to_csv("loan1.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
print(loan1.shape)
loan1.head()
# Out:
# (39717, 38)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... out_prncp out_prncp_inv  \
# 0   10.65%       162.87     B        B2  ...      0.00          0.00
# 1   15.27%        59.83     C        C4  ...      0.00          0.00
# 2   15.96%        84.33     C        C5  ...      0.00          0.00
# 3   13.49%       339.31     C        C1  ...      0.00          0.00
# 4   12.69%        67.79     B        B5  ...    524.06        524.06
#
#     total_pymnt total_pymnt_inv total_rec_prncp total_rec_int  \
# ...

# %% [markdown]
# All three below box plot shows similar patterns , with median of 10000 and outlayers

# %%
plt.boxplot(loan1.loan_amnt)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.boxplot(loan1.funded_amnt)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.boxplot(loan1.funded_amnt_inv)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# remove the current customers which are on track

# %%
loan1 = loan1[~(loan1["loan_status"] == 'Current')]

# %%
loan1.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
#
#   int_rate  installment grade sub_grade  ... out_prncp out_prncp_inv  \
# 0   10.65%       162.87     B        B2  ...       0.0           0.0
# 1   15.27%        59.83     C        C4  ...       0.0           0.0
# 2   15.96%        84.33     C        C5  ...       0.0           0.0
# 3   13.49%       339.31     C        C1  ...       0.0           0.0
# 5    7.90%       156.46     A        A4  ...       0.0           0.0
#
#     total_pymnt total_pymnt_inv total_rec_prncp total_rec_int  \
# ...

# %%
loan1.loan_status.value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64

# %% [markdown]
# plot the loan status against the purpose of the loan

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.distplot(loan1.funded_amnt_inv)
plt.show()

# %%
import seaborn as sns
sns.distplot(loan1.loan_amnt)
plt.show()

# %%
import seaborn as sns
sns.distplot(loan1.funded_amnt)
plt.show()

# %%
plt.scatter(loan1.home_ownership,loan1.funded_amnt)

# %%
def find_outliers_loan(x):
  q1 = np.percentile(x, 25)
  q3 = np.percentile(x, 75)

  iqr = q3-q1
  floor = q1 -1.5*iqr
  ceiling = q3 +1.5*iqr

  outlier_indices = list(x.index[ (x < floor)|(x > ceiling) ])
  outlier_values = list(x[outlier_indices])

  return outlier_indices, outlier_values

# %%
warnings.filterwarnings("ignore")
sns.jointplot(loan1.home_ownership,loan1.funded_amnt,kind='reg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-33-850589aed602> in <module>()
#       1 warnings.filterwarnings("ignore")
# ----> 2 sns.jointplot(loan1.home_ownership,loan1.funded_amnt,kind='reg')
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2311
#    2312         joint_kws.setdefault("color", color)
# -> 2313         grid.plot_joint(regplot, **joint_kws)
#    2314
# ...

# %% [markdown]
# people having own houses are less likely to take loans.
# most loans are between 4000 to 15000

# %%
loan1.purpose.value_counts()
# Out:
# debt_consolidation    18055
# credit_card            5027
# other                  3865
# home_improvement       2875
# major_purchase         2150
# small_business         1754
# car                    1499
# wedding                 926
# medical                 681
# moving                  576
# vacation                375
# house                   367
# educational             325
# renewable_energy        102
# Name: purpose, dtype: int64

# %%
loan1.purpose.describe()
# Out:
# count                  38577
# unique                    14
# top       debt_consolidation
# freq                   18055
# Name: purpose, dtype: object

# %%
plt.figure(figsize=[30,30])
sns.jointplot(loan1.purpose,loan1.funded_amnt,kind='reg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-36-ce3e28fd4cfc> in <module>()
#       1 plt.figure(figsize=[30,30])
# ----> 2 sns.jointplot(loan1.purpose,loan1.funded_amnt,kind='reg')
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2311
#    2312         joint_kws.setdefault("color", color)
# -> 2313         grid.plot_joint(regplot, **joint_kws)
#    2314
# ...

# %%
###sns.pairplot(loan1[["loan_status","int_rate","term"]])

# %% [markdown]
# cleaning data for plots

# %%
loan1["term"] = loan1["term"].apply(lambda x: x[:3])
loan1["int_rate"] =loan1["int_rate"].apply(lambda x: x[:-1])
loan1.int_rate.value_counts()
# Out:
# 10.99    913
# 11.49    790
# 7.51     787
# 13.49    749
# 7.88     725
#         ...
# 16.96      1
# 18.36      1
# 16.15      1
# 16.01      1
# 16.20      1
# Name: int_rate, Length: 370, dtype: int64

# %%
loan1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 39716
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       38577 non-null  int64
#  1   member_id                38577 non-null  int64
#  2   loan_amnt                38577 non-null  int64
#  3   funded_amnt              38577 non-null  int64
#  4   funded_amnt_inv          38577 non-null  float64
#  5   term                     38577 non-null  object
#  6   int_rate                 38577 non-null  object
#  7   installment              38577 non-null  float64
#  8   grade                    38577 non-null  object
#  9   sub_grade                38577 non-null  object
#  10  emp_length               38577 non-null  object
#  11  home_ownership           38577 non-null  object
#  12  annual_inc               38577 non-null  float64
#  13  verification_status      38577 non-null  object
# ...

# %% [markdown]
# remove not important variables

# %%
drop_list =['funded_amnt','funded_amnt_inv','installment','issue_d','url','zip_code','addr_state','delinq_2yrs','earliest_cr_line','inq_last_6mths','open_acc','pub_rec','revol_bal','total_acc','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee','last_pymnt_amnt']
loan1.drop(drop_list,axis =1,inplace=True)
loan1.to_csv("loan1.csv")

# %%
loan1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 39716
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   38577 non-null  int64
#  1   member_id            38577 non-null  int64
#  2   loan_amnt            38577 non-null  int64
#  3   term                 38577 non-null  object
#  4   int_rate             38577 non-null  object
#  5   grade                38577 non-null  object
#  6   sub_grade            38577 non-null  object
#  7   emp_length           38577 non-null  object
#  8   home_ownership       38577 non-null  object
#  9   annual_inc           38577 non-null  float64
#  10  verification_status  38577 non-null  object
#  11  loan_status          38577 non-null  object
#  12  purpose              38577 non-null  object
#  13  dti                  38577 non-null  float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 5.4+ MB

# %%
loan1.loan_status.value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64

# %% [markdown]
# plot between annual income and loan amount

# %%
plt.hist(loan1.loan_amnt)
# Out:
# (array([4985., 9771., 8011., 4903., 3989., 2991., 1155., 1631.,  437.,
#          704.]),
#  array([  500.,  3950.,  7400., 10850., 14300., 17750., 21200., 24650.,
#         28100., 31550., 35000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# abov graph show more loan amount is between 5000 to 10000

# %%
plt.hist(loan1.loan_amnt)
# Out:
# (array([4985., 9771., 8011., 4903., 3989., 2991., 1155., 1631.,  437.,
#          704.]),
#  array([  500.,  3950.,  7400., 10850., 14300., 17750., 21200., 24650.,
#         28100., 31550., 35000.]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib.pyplot as plt
plt.scatter(loan1.loan_amnt,loan1.annual_inc)

# %%
sns.jointplot(loan1.loan_amnt,loan1.annual_inc,kind='reg')

# %%
sns.jointplot(loan1.loan_amnt,loan1.emp_length,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-66e3c7e581ca> in <module>()
# ----> 1 sns.jointplot(loan1.loan_amnt,loan1.emp_length,kind='reg')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2311
#    2312         joint_kws.setdefault("color", color)
# -> 2313         grid.plot_joint(regplot, **joint_kws)
#    2314
#    2315     elif kind.startswith("resid"):
#
# ...

# %% [markdown]
# experiance class : 10+ years group has the highest loan amount

# %%
sns.jointplot(loan1.loan_amnt,loan1.grade,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-c79f2781e58e> in <module>()
# ----> 1 sns.jointplot(loan1.loan_amnt,loan1.grade,kind='reg')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2311
#    2312         joint_kws.setdefault("color", color)
# -> 2313         grid.plot_joint(regplot, **joint_kws)
#    2314
#    2315     elif kind.startswith("resid"):
#
# ...

# %%
sns.jointplot(loan1.loan_amnt,loan1.sub_grade,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-1430ce2a3d27> in <module>()
# ----> 1 sns.jointplot(loan1.loan_amnt,loan1.sub_grade,kind='reg')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2311
#    2312         joint_kws.setdefault("color", color)
# -> 2313         grid.plot_joint(regplot, **joint_kws)
#    2314
#    2315     elif kind.startswith("resid"):
#
# ...

# %%
loan_fp=loan1[loan1["loan_status"]=="Fully Paid"]
loan_charged=loan1[loan1["loan_status"]=="Charged Off"]

fig, ax = plt.subplots(nrows=2, figsize=(15,10))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(loan_fp["loan_amnt"], ax=ax[0],color="g")
g1 = sns.distplot(loan_charged["loan_amnt"], ax=ax[0],color='r')

g1.set_title("loan_amnt Distribuition", fontsize=15)
g1.set_xlabel("loan_amnt")
g1.set_xlabel("loan_status")


#g2 = sns.countplot(x="purpose",data=loan1,palette="hls", ax=ax[1],hue = "dti")
g2 = sns.countplot(x="purpose",data=loan1,palette="hls", ax=ax[1])
g2.set_title("purpose Counting by dti", fontsize=15)
g2.set_xlabel("purpose")


plt.show()

# %%
loan_fp=loan1[loan1["loan_status"]=="Fully Paid"]
loan_charged=loan1[loan1["loan_status"]=="Charged Off"]

fig, ax = plt.subplots(nrows=2, figsize=(25,10))
#plt.subplots_adjust(hspace = 0.4, top = 0.8)

g1 = sns.distplot(loan_fp["loan_amnt"], ax=ax[0],color="g")
g1 = sns.distplot(loan_charged["loan_amnt"], ax=ax[0],color='r')

g1.set_title("loan_amnt Distribuition Fully paid and default comparison", fontsize=15)
g1.set_ylabel("loan_amnt")
g1.set_xlabel("loan_status")

g2 = sns.countplot(x="purpose",data=loan1,palette="hls", ax=ax[1])
g2.set_title("purpose Counting ", fontsize=15)
g2.set_xlabel("purpose")
#g2 = sns.countplot(x="purpose",data=loan1,palette="hls", ax=ax[1],hue = "dti")


plt.show()

# %%
fig, ax = plt.subplots(nrows=2, figsize=(25,10))
g3 = sns.distplot(loan_fp["loan_amnt"], ax=ax[0],color="g")
g3 = sns.distplot(loan_charged["loan_amnt"], ax=ax[0],color='r')

g3.set_title("loan_amnt Distribuition Fully paid and default comparison against purpose", fontsize=15)


g3 = sns.countplot(x="purpose",data=loan1,palette="hls", ax=ax[1],hue = "loan_status")
g3.set_title("purpose and loan status ", fontsize=15)
g3.set_xlabel("purpose")


plt.show()

# %%
fig, ax1 = plt.subplots(nrows=2, figsize=(25,10))
g3 = sns.distplot(loan_fp["loan_amnt"], ax=ax1[0],color="g")
g3 = sns.distplot(loan_charged["loan_amnt"], ax=ax1[0],color='r')

g3.set_title("loan_amnt Distribuition grade and sub grade comparison against purpose", fontsize=15)

g3 = sns.countplot(x="purpose",data=loan1,palette="hls", ax=ax1[1],hue = "grade")
g3.set_title("purpose and grade ", fontsize=15)
g3.set_xlabel("purpose")

g3 = sns.countplot(x="purpose",data=loan1,palette="hls", ax=ax1[1],hue = "sub_grade")
g3.set_title("purpose and sub grade ", fontsize=15)
g3.set_xlabel("purpose")

plt.legend(bbox_to_anchor=(1, 1), loc='bottom left', borderaxespad=0)
plt.show()

# %%
table = pd.pivot_table(loan1, values ='purpose', index =['loan_status'],columns =['verification_status'],  aggfunc='count' )

table
# Out:
# verification_status  Not Verified  Source Verified  Verified
# loan_status
# Charged Off                  2142             1434      2051
# Fully Paid                  14552             8243     10155
